# %%
# !pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org selenium

# %%
import requests
import pandas as pd

matchids = ["1422119",	"1422120",	"1422121",	"1422122",	"1422123",	"1422124",	"1422125",	
            "1422126",	"1422127",	"1422128",	"1422129",	"1422130",	"1422131",	"1422132",	
            "1422133",	"1422134",	"1422135",	"1422136",	"1422137",	"1422138",	"1422139",	
            "1426260",	"1426261",	"1426262",	"1426263",	"1426264",	"1426265",	"1426266",	
            "1426267",	"1426268",	"1426269",	"1426270",	"1426271",	"1426272",	"1426273",	
            "1426274",	"1426275",	"1426276",	"1426277",	"1426278",	"1426279",	"1426280",	
            "1426281",	"1426282",	"1426283",	"1426284",	"1426285",	"1426286",	"1426287",	
            "1426288",	"1426289",	"1426290",	"1426291",	"1426292",	"1426293",	"1426294",
            "1426295",	"1426296",	"1426297",	"1426298",	"1426299",	"1426300",	"1426302",
            "1426303",	"1426305",	"1426306",	"1426307",	"1426309",	"1426310"
]


headers = {
        'accept': 'application/json',
        'User-Agent': 'Your User Agent',  # Set an appropriate user agent

    }

#url = "https://hs-consumer-api.espncricinfo.com/v1/pages/match/scorecard"
url = "https://hs-consumer-api.espncricinfo.com/v1/pages/match/home"
#url = "https://hs-consumer-api.espncricinfo.com/v1/pages/match/overs/details"

# Create an empty DataFrame
data = []

for matchid in matchids:
    params = {
        'lang': 'en',
        'seriesId': 1410320,
         'matchId': matchid,
         #'mode': 'ALL',
    }

    response = requests.get(url, params=params, headers=headers, verify=False, allow_redirects=True)
    scorecard = response.json()
    #print(scorecard)    

   # Get the slug
    slug = scorecard['match']['slug']
    print(slug)

    # Append the match ID and slug to the DataFrame
    data.append({'match_id': matchid, 'slug': slug})

df_slug = pd.DataFrame(data)

#

# %%
df_slug.to_csv('C:/Users/kripa.krishnan/OneDrive - Precision For Medicine/Desktop/df_slug.csv', index=False)

# %%
#scorecard['match']['statusText']
stats = scorecard['inningOvers'][1]['stats']

stats[1]['']

#df.to_csv('C:/Users/kripa.krishnan/OneDrive - Precision For Medicine/Desktop/df_analysis_!.csv', index=False)

# %%
import requests

def getMatchData(seriesId, matchId):
    url = "https://hs-consumer-api.espncricinfo.com/v1/pages/match/overs/details"
    params = {
        'lang': 'en',
        'seriesId': seriesId,
        'matchId': matchId,
        'mode': 'ALL',
    }
    headers = {
        'accept': 'application/json',
        'User-Agent': 'Your User Agent',  # Set an appropriate user agent

    }
    response = requests.get(url, params=params, headers=headers, verify=False, allow_redirects=True)
    return response.json()

# %%
full_data = getMatchData('1410320', '1426288')
first_innings = full_data['inningOvers'][0]['stats']
second_innings = full_data['inningOvers'][1]['stats']

# example win probability on 11th over
balls = second_innings[18]['balls']
balls[1]['pitchLine']
# Out:
# c:\Program Files\Python311\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'hs-consumer-api.espncricinfo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 'ON_THE_STUMPS'

# %%
import requests
from bs4 import BeautifulSoup
import re


# Replace 'URL' with the actual URL of the page you want to scrape
url = 'https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/kolkata-knight-riders-vs-delhi-capitals-47th-match-1426285/ball-by-ball-commentary'

# Send a GET request to the URL
response = requests.get(url, verify = False)
soup = BeautifulSoup(response.content, 'html.parser')

#<div class="ds-flex ds-flex-col ds-text-typo ds-text-right"><span class="ds-text-tight-s ds-font-bold">KKR: 141/3</span><span class=""><span>CRR: 9.40</span>&nbsp;<span class="no-wrap">• RRR: 2.60</span><br><span>Need 13 from 30b</span></span></div>

tr_elements = soup.find_all('tbody')
#print(tr_elements)
spans = soup.find_all('span')
print(spans)
for span in spans:
  print(span.text.strip('"'))


# def get_details_for_each_tr(element, result_list):
#     # Find all 'tr' elements
#     tr_elements = element.find_all('td')
#     #print(tr_elements)
#      # Iterate over each <tr> element and access its details.
#     for tr in tr_elements:
#         # Access data within each <tr> element, e.g., find <td> elements.
#         td_elements = tr.find_all('div')
#         print(td_elements)
#         #for td in td_elements:
#             #print(td.text)  # Print the text content of each <td>.
# #     # Iterate over each 'tr' element
# #     for tr in tr_elements:
        
# #             # Find the 'span' element with class 'ds-text-compact-xs' within this 'tr' element
# #             span = tr.find('span', class_='ds-text-compact-xs ds-mx-1')
# #             div = tr.select('div', class_='df-flex df-flex-wrap')
# #             last_tag = div_tags[-1] if div else None
# #             print(last_tag)
# #             if span:
# #             # Get the text content of the 'span' element
# #                     text_content = span.get_text(strip=True)
                    
# #             # Check if the text content contains a '%' symbol
# #                     if '%' in text_content:
# #                 # If it does, append the text content to the result list
# #                         result_list.append(text_content) 

# # Create an empty list to store the results
# result_list = []

# # Call the function with the soup object and the results list
# get_details_for_each_tr(soup.body, result_list)

#result_list

# %%
import requests
from bs4 import BeautifulSoup
from espncricinfo.exceptions import MatchNotFoundError, NoSeriesError

class Series(object):

    def __init__(self, series_id):
        self.series_id = series_id
        self.json_url = "http://core.espnuk.org/v2/sports/cricket/leagues/{0}/".format(str(series_id))
        self.events_url = "http://core.espnuk.org/v2/sports/cricket/leagues/{0}/events".format(str(series_id))
        self.seasons_url = "http://core.espnuk.org/v2/sports/cricket/leagues/{0}/seasons".format(str(series_id))
        self.headers = {'user-agent': 'Mozilla/5.0'}
        self.json = self.get_json(self.json_url)
        self.seasons = self._get_seasons()
        self.years = self._get_years_from_seasons()
        if self.json:
            self.name = self.json['name']
            self.short_name = self.json['shortName']
            self.abbreviation = self.json['abbreviation']
            self.slug = self.json['slug']
            self.is_tournament = self.json['isTournament']
            self.url = self.json['links'][0]['href']
            self.events_json = self._get_events()

        if self.events_json:
            self.events = self._build_events()

    def get_json(self, url):
        r = requests.get(url,headers=self.headers, verify = False)
        if r.status_code == 404:
            raise "Not Found"
        else:
            return r.json()

    def __str__(self):
        return self.name

    def __unicode__(self):
        return self.name

    def _get_seasons(self):
        season_json = self.get_json(self.seasons_url)
        if season_json:
            return [x['$ref'] for x in season_json['items']]
        else:
            return None

    def _get_years_from_seasons(self):
        return [x.split('/')[9] for x in self.seasons]

    def _get_events(self):
        events_json = self.get_json(self.events_url)
        if events_json:
            return [x for x in events_json['items']]
        else:
            return None

    def _build_events(self):
        events = []
        for event in self.events_json:
            events.append(self.get_json(event['$ref']))
        return events

# %%
import requests
from bs4 import BeautifulSoup
import re

# Replace with the actual URL you want to scrape
url = "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/match-schedule-fixtures-and-results"

# Send an HTTP request to the URL
response = requests.get(url, verify = False)

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(response.content, 'html.parser')

# Find all <a> tags (links)
link_tags = soup.find_all('a')

filtered_id_list = []



# Extract numeric values from the href attributes
for link in link_tags:
    href = link.get('href')
    numeric_values = re.findall(r'\d+', href)  # Extract all numeric values
    if numeric_values:
        print(f"Link: {href}, Numeric Values: {', '.join(numeric_values)}")
    else:
        print(f"No numeric values found in link: {href}")

                # Filter out all 7-digit numeric values
    filtered_ids = [match for match in numeric_values if match.isdigit() and match != '1410320']

# Print the filtered IDs
    for link_id in filtered_ids:
        if link_id.isdigit() and link_id != '1410320':
            filtered_id_list.append(link_id)



# # Extract the integer IDs from the href attributes
# for link in link_tags:
#     href = link.get('href')
#     match = re.search(r'/(\d{7})', href)  # Adjust the regex pattern as needed
#     if match:
#         link_id = match.group(1)
#         print(f"Link: {href}, ID: {link_id}")

# %%
filtered_id_list

# %%
# Filter for 7-digit integers starting with '1422'


seven_digit_integers = [int(num) for num in filtered_id_list if num.isdigit() and 1_000_000 <= int(num) < 10_000_000 and num.startswith('142')]
def get_unique_list(input_list):
    unique_list = []
    for item in input_list:
        if item not in unique_list:
            unique_list.append(item)
    return unique_list

unique_values = get_unique_list(seven_digit_integers)
unique_values.sort()

# %%
# Find the indices of the start and end values
start_index = unique_values.index(1426310)
end_index = unique_values.index(1422119)

print(unique_values)
# Out:
# [1422119, 1422120, 1422121, 1422122, 1422123, 1422124, 1422125, 1422126, 1422127, 1422128, 1422129, 1422130, 1422131, 1422132, 1422133, 1422134, 1422135, 1422136, 1422137, 1422138, 1422139, 1426260, 1426261, 1426262, 1426263, 1426264, 1426265, 1426266, 1426267, 1426268, 1426269, 1426270, 1426271, 1426272, 1426273, 1426274, 1426275, 1426276, 1426277, 1426278, 1426279, 1426280, 1426281, 1426282, 1426283, 1426284, 1426285, 1426286, 1426287, 1426288, 1426289, 1426290, 1426291, 1426292, 1426293, 1426294, 1426295, 1426296, 1426297, 1426298, 1426299, 1426300, 1426301, 1426302, 1426303, 1426304, 1426305, 1426306, 1426307, 1426308, 1426309, 1426310, 1426311, 1426312, 1428145, 1428154]

# %%
full_data = getMatchData('1410320', '1422124')
print(full_data)
first_innings = full_data['inningOvers'][0]['stats']
second_innings = full_data['inningOvers'][1]['stats']



# example win probability on 11th over
balls = first_innings[1]['balls']
range(len(balls))

# %%
# Initialize an empty dictionary to store the results
rows = []

# Iterate over each ID and call the function for indices 1 to 20
for id in unique_values:
    # Replace the second ID in the original code with the current ID
    full_data = getMatchData('1410320', id)
    # Check if the data for the current ID is available
    # Check if the data for the current ID is available
    if full_data:
        
        # Check if predictions exist for the first innings
        if 'inningOvers' in full_data and full_data['inningOvers'] and full_data['inningOvers'] is not None:
            
            predictions = full_data['inningOvers'][1]['stats']
            #print(range(len(predictions)))
            # Extract the predictions for indices 1 to 20
            for i in range(len(predictions)):
                if predictions[i]['predictions'] is not None:
                    #print(predictions[i])
                    #second_innings = predictions[i]['predictions']['winProbability']
                    balls = predictions[i]['balls']
                    #print(range(len(balls)))
                    
                    for j in range(len(balls)):
                        bowler_stat = balls[j].get('bowlerStatText', 'N/A')
                        # if bowler_stat:
                        #    bowler_stats.append(bowler_stat) 
                           #print(bowler_stat)
                        pitchline1 = balls[j].get('pitchLine', 'N/A') 
                        # if pitchline1:
                        #     pitchline.append(pitchline1)
                        pitchlength1 = balls[j].get('pitchLength', 'N/A') 
                        # if pitchlength1:
                        #     pitchlength.append(pitchlength1)
                        
                        ball_pred = balls[j]['predictions'].get('winProbability')
                          

                        row = { 
                            'id' : id,
                            'over': i,
                            'ball': j, 
                            'bowler_stat' : bowler_stat ,
                                'pitchline1' : pitchline1,
                   
                        'pitchlength1' : pitchlength1 ,
                            'ball_pred' : ball_pred 

                        }  

                        rows.append(row) 


                              
                    #results_by_id[f"{id}_{i}_{j}"] = {'WinProbability': win_probs, 'BowlerStatus': bowler_stats,
                    #                              'PitchLine': pitchline, 'PitchLength': pitchlength} 
            else:
                print(f"No predictions available for index {i} of ID {id}.")
        else:
            print(f"No inning data available for ID {id}.")
    else:
        print(f"Skipping ID {id} as no data is available.")


       # Store the predictions in the results dictionary

final_df = pd.DataFrame(rows)                      
# Now you can access the predictions for each ID and index
#for key, second_innings in results_by_id.items():
#    print(f"Predictions for {key}: {second_innings}")

# %%
final_df
# Out:
#            id  over  ball                                        bowler_stat  \
# 0     1422119     0     0  {'short': 'Mohammed Siraj 0.1-0-4-0', 'long': ...
# 1     1422119     0     1  {'short': 'Mohammed Siraj 0.2-0-4-0', 'long': ...
# 2     1422119     0     2  {'short': 'Mohammed Siraj 0.3-0-4-0', 'long': ...
# 3     1422119     0     3  {'short': 'Mohammed Siraj 0.4-0-4-0', 'long': ...
# 4     1422119     0     4  {'short': 'Mohammed Siraj 0.5-0-8-0', 'long': ...
# ...       ...   ...   ...                                                ...
# 8014  1426310    18     1  {'short': 'LH Ferguson 3.2-0-31-1', 'long': 'L...
# 8015  1426310    18     2  {'short': 'LH Ferguson 3.3-0-31-1', 'long': 'L...
# 8016  1426310    18     3  {'short': 'LH Ferguson 3.4-0-31-1', 'long': 'L...
# 8017  1426310    18     4  {'short': 'LH Ferguson 3.5-0-31-1', 'long': 'L...
# 8018  1426310    18     5  {'short': 'LH Ferguson 4-0-37-1', 'long': 'Loc...
#
# ...

# %%
final_df.to_csv('C:/Users/kripa.krishnan/OneDrive - Precision For Medicine/Desktop/df_analysis_new1.csv', index=False)

# %%
import pandas as pd
# Split keys into separate columns
df = pd.DataFrame(results_by_id.items(), columns=['ID', 'Win_Probability'])


# Extract the number after the underscore and colon
df['ID_before_underscore'] = df['ID'].apply(lambda x: x.split('_')[0])
df['Number_after_underscore'] = df['ID'].apply(lambda x: int(x.split('_')[1]))

# Split the combined lists into separate columns
df[['Win_Probability', 'BowlerStatus', 'PitchLength', 'PitchLine']] = pd.DataFrame(df['Win_Probability'].tolist(), index=df.index)

# Explode the lists to create individual rows
#df = df.explode('BowlerStatus')


#df
# Display the resulting DataFrame
#df.to_csv('C:/Users/kripa.krishnan/OneDrive - Precision For Medicine/Desktop/df_analysis_new1.csv', index=False)

# %%
df
# Out:
#                 ID                                    Win_Probability  \
# 0      1422119_0_0  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 1      1422119_0_1  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 2      1422119_0_2  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 3      1422119_0_3  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 4      1422119_0_4  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# ...            ...                                                ...
# 8014  1426310_18_1  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 8015  1426310_18_2  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 8016  1426310_18_3  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 8017  1426310_18_4  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
# 8018  1426310_18_5  [52.33, 51.4, 50.44, 48.81, 52.48, 51.6, 54.63...
#
#      ID_before_underscore  Number_after_underscore  \
# 0                 1422119                        0
# ...

# %%
import json
import requests
from bs4 import BeautifulSoup
from espncricinfo.exceptions import MatchNotFoundError, NoScorecardError

class Match(object):

    def __init__(self, match_id):
        self.match_id = match_id
        self.match_url = "https://www.espncricinfo.com/matches/engine/match/{0}.html".format(str(match_id))
        self.json_url = "https://www.espncricinfo.com/matches/engine/match/{0}.json".format(str(match_id))
        self.headers = {'user-agent': 'Mozilla/5.0'}
        self.json = self.get_json()
        self.html = self.get_html()
        self.comms_json = self.get_comms_json()
        if self.json:
            self.__unicode__ = self._description()
            self.status = self._status()
            self.match_class = self._match_class()
            self.season = self._season()
            self.description = self._description()
            self.legacy_scorecard_url = self._legacy_scorecard_url()
            self.series = self._series()
            self.series_name = self._series_name()
            self.series_id = self._series_id()
            self.event_url = "http://core.espnuk.org/v2/sports/cricket/leagues/{0}/events/{1}".format(str(self.series_id), str(match_id))
            self.details_url = self._details_url()
            self.officials = self._officials()
            self.current_summary = self._current_summary()
            self.present_datetime_local = self._present_datetime_local()
            self.present_datetime_gmt = self._present_datetime_gmt()
            self.start_datetime_local = self._start_datetime_local()
            self.start_datetime_gmt = self._start_datetime_gmt()
            self.cancelled_match = self._cancelled_match()
            self.rain_rule = self._rain_rule()
            self.date = self._date()
            self.continent = self._continent()
            self.town_area = self._town_area()
            self.town_name = self._town_name()
            self.town_id = self._town_id()
            self.weather_location_code = self._weather_location_code()
            self.match_title = self._match_title()
            self.result = self._result()
            self.ground_id = self._ground_id()
            self.ground_name = self._ground_name()
            self.lighting = self._lighting()
            self.followon = self._followon()
            self.scheduled_overs = self._scheduled_overs()
            self.innings_list = self._innings_list()
            self.innings = self._innings()
            self.latest_batting = self._latest_batting()
            self.latest_bowling = self._latest_bowling()
            self.latest_innings = self._latest_innings()
            self.latest_innings_fow = self._latest_innings_fow()
            self.team_1 = self._team_1()
            self.team_1_id = self._team_1_id()
            self.team_1_abbreviation = self._team_1_abbreviation()
            self.team_1_players = self._team_1_players()
            self.team_1_innings = self._team_1_innings()
            self.team_1_run_rate = self._team_1_run_rate()
            self.team_1_overs_batted = self._team_1_overs_batted()
            self.team_1_batting_result = self._team_1_batting_result()
            self.team_2 = self._team_2()
            self.team_2_id = self._team_2_id()
            self.team_2_abbreviation = self._team_2_abbreviation()
            self.team_2_players = self._team_2_players()
            self.team_2_innings = self._team_2_innings()
            self.team_2_run_rate = self._team_2_run_rate()
            self.team_2_overs_batted = self._team_2_overs_batted()
            self.team_2_batting_result = self._team_2_batting_result()
            if not self.status == 'dormant':
                self.home_team = self._home_team()
                self.batting_first = self._batting_first()
                self.match_winner = self._match_winner()
                self.toss_winner = self._toss_winner()
                self.toss_decision = self._toss_decision()
                self.toss_decision_name = self._toss_decision_name()
                self.toss_choice_team_id = self._toss_choice_team_id()
                self.toss_winner_team_id = self._toss_winner_team_id()
                self.espn_api_url = self._espn_api_url()
                # from comms_json
                self.rosters = self._rosters()
                self.all_innings = self._all_innings()


    def __str__(self):
        return self.description

    def __repr__(self):
        return (f'{self.__class__.__name__}('f'{self.match_id!r})')

    def get_json(self):
        r = requests.get(self.json_url,headers=self.headers, verify = False)
        if r.status_code == 404:
            raise MatchNotFoundError
        elif 'Scorecard not yet available' in r.text:
            raise NoScorecardError
        else:
            return r.json()

    def get_html(self):
        r = requests.get(self.match_url,headers=self.headers, verify = False)
        if r.status_code == 404:
            raise MatchNotFoundError
        else:
            return BeautifulSoup(r.text, 'html.parser')

    def match_json(self):
        return self.json['match']

    def innings_comms_url(self, innings=1, page=1):
        return f"https://hsapi.espncricinfo.com/v1/pages/match/comments?lang=en&leagueId={self.series_id}&eventId={self.match_id}&period={innings}&page={page}&filter=full&liveTest=false"

    def get_comms_json(self):
        try:
            text = self.html.find_all('script')[15].string
            return json.loads(text)
        except:
            return None

    def _espn_api_url(self):
        return "https://site.api.espn.com/apis/site/v2/sports/cricket/{0}/summary?event={1}".format(self.series_id, self.match_id)

    def _legacy_scorecard_url(self):
        return "https://static.espncricinfo.com"+self.match_json()['legacy_url']

    def _details_url(self, page=1, number=1000):
        return self.event_url+"/competitions/{0}/details?page_size={1}&page={2}".format(str(self.match_id), str(number), str(page))

    def __str__(self):
        return self.json['description']

    def __unicode__(self):
        return self.json['description']

    def _status(self):
        return self.match_json()['match_status']

    def _match_class(self):
        if self.match_json()['international_class_card'] != "":
            return self.match_json()['international_class_card']
        else:
            return self.match_json()['general_class_card']

    def _season(self):
        return self.match_json()['season']

    def _description(self):
        return self.json['description']

    def _series(self):
        return self.json['series']

    def _series_name(self):
        try:
            return self.json['series'][-1]['series_name']
        except:
            return None

    def _series_id(self):
        return self.json['series'][-1]['core_recreation_id']

    def _officials(self):
        return self.json['official']

    # live matches only
    def _current_summary(self):
        return self.match_json().get('current_summary')

    def _present_datetime_local(self):
        return self.match_json()['present_datetime_local']

    def _present_datetime_gmt(self):
        return self.match_json()['present_datetime_gmt']

    def _start_datetime_local(self):
        return self.match_json()['start_datetime_local']

    def _start_datetime_gmt(self):
        return self.match_json()['start_datetime_gmt']

    def _cancelled_match(self):
        if self.match_json()['cancelled_match'] == 'N':
            return False
        else:
            return True

    def _rain_rule(self):
        if self.match_json().get('rain_rule') == "1":
            return self.match_json()['rain_rule_name']
        else:
            return None

    def _date(self):
        return self.match_json()['start_date_raw']

    def _continent(self):
        return self.match_json().get('continent_name')

    def _town_area(self):
        return self.match_json().get('town_area')

    def _town_name(self):
        return self.match_json().get('town_name')

    def _town_id(self):
        return self.match_json().get('town_id')

    def _weather_location_code(self):
        return self.match_json().get('weather_location_code')

    def _match_title(self):
        return self.match_json()['cms_match_title']

    def _result(self):
        return self.json['live']['status']

    def _ground_id(self):
        return self.match_json()['ground_id']

    def _ground_name(self):
        return self.match_json()['ground_name']

    def _lighting(self):
        return self.match_json()['floodlit_name']

    def _followon(self):
        if self.match_json().get('followon') == '1':
            return True
        else:
            return False

    def _scheduled_overs(self):
        try:
            return int(self.match_json()['scheduled_overs'])
        except:
            return None

    def _innings_list(self):
        try:
            return self.json['centre']['common']['innings_list']
        except:
            return None

    def _innings(self):
        return self.json['innings']

    def _latest_batting(self):
        try:
            return self.json['centre']['common']['batting']
        except:
            return None

    def _latest_bowling(self):
        try:
            return self.json['centre']['common']['bowling']
        except:
            return None

    def _latest_innings(self):
        try:
            return self.json['centre']['common']['innings']
        except:
            return None

    def _latest_innings_fow(self):
        return self.json['centre'].get('fow')

    def _team_1(self):
        return self.json['team'][0]

    def _team_1_id(self):
        return self._team_1()['team_id']

    def _team_1_abbreviation(self):
        return self._team_1()['team_abbreviation']

    def _team_1_players(self):
        return self._team_1().get('player', [])

    def _team_1_innings(self):
        try:
            return [inn for inn in self.json['innings'] if inn['batting_team_id'] == self._team_1_id()][0]
        except:
            return None

    def _team_1_run_rate(self):
        try:
            return float(self._team_1_innings()['run_rate'])
        except:
            return None

    def _team_1_overs_batted(self):
        try:
            return float(self._team_1_innings()['overs'])
        except:
            return None

    def _team_1_batting_result(self):
        try:
            return self._team_1_innings()['event_name']
        except:
            return None

    def _team_2(self):
        return self.json['team'][1]

    def _team_2_id(self):
        return self._team_2()['team_id']

    def _team_2_abbreviation(self):
        return self._team_2()['team_abbreviation']

    def _team_2_players(self):
        return self._team_2().get('player', [])

    def _team_2_innings(self):
        try:
            return [inn for inn in self.json['innings'] if inn['batting_team_id'] == self._team_2_id()][0]
        except:
            return None

    def _team_2_run_rate(self):
        try:
            return float(self._team_2_innings()['run_rate'])
        except:
            return None

    def _team_2_overs_batted(self):
        try:
            return float(self._team_2_innings()['overs'])
        except:
            return None

    def _team_2_batting_result(self):
        try:
            return self._team_2_innings()['event_name']
        except:
            return None

    def _home_team(self):
        if self._team_1_id() == self.match_json()['home_team_id']:
            return self._team_1_abbreviation()
        else:
            return self._team_2_abbreviation()

    def _batting_first(self):
        if self._team_1_id() == self.match_json()['batting_first_team_id']:
            return self._team_1_abbreviation()
        else:
            return self._team_2_abbreviation()

    def _match_winner(self):
        if self._team_1_id() == self.match_json()['winner_team_id']:
            return self._team_1_abbreviation()
        else:
            return self._team_2_abbreviation()

    def _toss_winner(self):
        if self._team_1_id() == self.match_json()['toss_winner_team_id']:
            return self._team_1_id()
        else:
            return self._team_2_id()

    def _toss_decision(self):
        if self.match_json()['toss_decision'] == '' and len(self.innings) > 0:
            if self.innings[0]['batting_team_id'] == self.toss_winner:
                decision = '1'
            else:
                decision = '2'
        else:
            decision = self.match_json()['toss_decision']
        return decision

    def _toss_decision_name(self):
        if self.match_json()['toss_decision_name'] == '' and len(self.innings) > 0:
            if self.innings[0]['batting_team_id'] == self.toss_winner:
                decision_name = 'bat'
            else:
                decision_name = 'bowl'
        else:
            decision_name = self.match_json()['toss_decision_name']
        return decision_name

    def _toss_choice_team_id(self):
        return self.match_json()['toss_choice_team_id']

    def _toss_winner_team_id(self):
        return self.match_json()['toss_winner_team_id']

    # comms_json methods

    def _rosters(self):
        try:
            return self.comms_json['props']['pageProps']['data']['pageData']['content']['matchPlayers']
        except:
            return None

    def _all_innings(self):
        try:
            return self.comms_json['props']['pageProps']['data']['pageData']['content']['scorecard']['innings']
        except:
            return self.json['innings']

    def batsmen(self, innings):
        try:
            return self.comms_json['props']['pageProps']['data']['pageData']['content']['scorecard']['innings'][str(innings)]['inningBatsmen']
        except:
            return None

    def bowlers(self, innings):
        try:
            return self.comms_json['props']['pageProps']['data']['pageData']['content']['scorecard']['innings'][str(innings)]['inningBowlers']
        except:
            return None

    def extras(self, innings):
        try:
            return self.comms_json['props']['pageProps']['data']['pageData']['content']['scorecard']['innings'][str(innings)]['extras']
        except:
            return None

    def fows(self, innings):
        try:
            return self.comms_json['props']['pageProps']['data']['pageData']['content']['scorecard']['innings'][str(innings)]['inningFallOfWickets']
        except:
            return None

    @staticmethod
    def get_recent_matches(date=None):
        if date:
            url = "https://www.espncricinfo.com/ci/engine/match/index.html?date=%sview=week" % date
        else:
            url = "https://www.espncricinfo.com/ci/engine/match/index.html?view=week"
        r = requests.get(url,headers={'user-agent': 'Mozilla/5.0'})
        soup = BeautifulSoup(r.text, 'html.parser')
        return [x['href'].split('/',4)[4].split('.')[0] for x in soup.findAll('a', href=True, text='Scorecard')]

# %%
match_instance = Match(1422121)
print(match_instance.toss_winner)

# self.home_team = self._home_team()
#                 self.batting_first = self._batting_first()
#                 self.match_winner = self._match_winner()
#                 self.toss_winner = self._toss_winner()
# Out:
# c:\Program Files\Python311\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.espncricinfo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Program Files\Python311\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.espncricinfo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Program Files\Python311\Lib\site-packages\urllib3\connectionpool.py:1095: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.espncricinfo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ...

# %%
import requests
from bs4 import BeautifulSoup
from espncricinfo.match import Match

class Summary(object):

    def __init__(self):
        self.url = "http://static.cricinfo.com/rss/livescores.xml"
        self.headers = {'user-agent': 'Mozilla/5.0'}
        self.xml = self.get_xml()
        self.match_ids = self._match_ids()
        self.matches = self._build_matches()

    def get_xml(self):
        r = requests.get(self.url, headers=self.headers, verify = False)
        if r.status_code == 404:
            raise MatchNotFoundError
        else:
            return BeautifulSoup(r.text, 'xml')
        
    def _match_ids(self):
        matches = [x.link.text.split(".html")[0].split('/')[6] for x in self.xml.findAll('item')]
        return matches

    def _build_matches(self):
        return [Match(m) for m in self.match_ids]

# %%
summary_instance = Summary()
summary_instance.match_ids
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 summary_instance = Summary()
#       2 summary_instance.match_ids
#
# NameError: name 'Summary' is not defined

# %%
# !pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org python-docx

# %%
# !pip install --trusted-host pypi.org --trusted-host pypi.python.org --trusted-host files.pythonhosted.org doltpy

# %%
import os
import urllib3
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
urllib3.disable_warnings()

def download_csv_files(dataset, output_folder):
    # Create the output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    for row in dataset:
        url = row['url']
        try:
            # Get the HTML content of the URL
            response = requests.get(url, verify= False)
            response.raise_for_status()  # Raise an exception if the request failed

            # Parse the HTML content
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all links to CSV files
            csv_links = [link.get('href') for link in soup.find_all('a', href=lambda href: href and '.csv' in href)]
            
            # Download each CSV file
            for csv_link in csv_links:
                # Join the base URL and the relative CSV link
                absolute_csv_link = urljoin(url, csv_link)

                # Extract the filename from the URL
                filename = os.path.basename(urlparse(absolute_csv_link).path)
                print('hi')
                # Download the CSV file
                csv_response = requests.get(absolute_csv_link, verify = False)
                print("hi")
                csv_response.raise_for_status()  # Raise an exception if the request failed

                # Save the CSV file to the output folder
                with open(os.path.join(output_folder, filename), 'wb') as file:
                    file.write(csv_response.content)

                print(f"Downloaded {filename} from {absolute_csv_link}")
        except requests.exceptions.RequestException as e:
            print(f"Error occurred while processing {url}: {e}")

# Usage example
dataset = [
#     {"url":"https://www.abingtonhealth.org/app/security/login.aspx"},
# {"url":"https://www.pennmedicine.org/for-patients-and-visitors/patient-information/insurance-and-billing/financial-transparency"},
# {"url":"https://www.chop.edu/centers-programs/billing-and-insurance/understanding-hospital-charges"},
# {"url":"https://www.uclahealth.org/patients-families/billing-insurance/price-transparency/machine-readable-files"},
# {"url":"https://towerhealth.org/locations/chestnut-hill-hospital/billing/hospital-pricing-chestnut-hill-hospital"},
# {"url":"https://www.einstein.edu/"},
# {"url":"https://www.nemours.org/patientfamily/hospital-charges.html"},
# {"url":"https://www.atlanticare.org/patients-and-visitors/for-patients/billing-and-insurance/hospital-charge-list"},
# {"url":"https://www.cooperhealth.org/patients-visitors/financial-matters/chargemaster"},
# {"url":"https://www.crozerhealth.org/financial-resources/hospital-price-transparency/"},
# {"url":"https://demanddeborah.org/patients-and-visitors/patient-resources/financial-information/#"},
# {"url":"https://www.doylestownhealth.org/patients-and-visitors/billing-and-finance#maintabbed-content-tab-76DDC467-6E90-4E4E-BD1E-FFFFDC0A930B-2-2"},
# {"url":"https://www.eagleville.org/about-us-old/price-transparency-charge-master/"},
# {"url":"https://www.gvh.org/charge-transparency/"},
# {"url":""},
# {"url":"https://www.inspirahealthnetwork.org/patients-visitors/billing-online-payments/bill-transparency"},
# {"url":"https://www.templehealth.org/pricing-disclaimer"},
# {"url":"https://www.jeffersonhealth.org/pay-my-bill/charge-description"},
# {"url":"https://www.virtua.org/patient-tools/hospital-charges-information"},
# {"url":"https://www.lowerbuckshosp.com/patients-visitors/financial-assistance/"},
# {"url":"https://www.mainlinehealth.org/patient-services/patient-billing/price-transparency/standard-charges"},
# {"url":"https://www.cdmpricing.com/e6d322b39e32a0ef6a713b0127a22def/standard-charges"},
# {"url":"https://www.cdmpricing.com/8873527e6925184d69fb58c9cc80b9c5/standard-charges"},
# {"url":"https://www.cdmpricing.com/b5330b717ebbf0a3f044ab69201cdf92/standard-charges"},
# {"url":"https://www.cdmpricing.com/67f6c21471749d14e20695fbcfb471d9/standard-charges"},
# {"url":"https://towerhealth.org/locations/phoenixville-hospital/billing/hospital-pricing-phoenixville-hospital"},
# {"url":"https://www.phycarehospital.com/pay-online.html"},
# {"url":"https://towerhealth.org/locations/pottstown-hospital/billing/hospital-pricing-pottstown-hospital"},
# {"url":"https://rothmanorthohospital.com/for-patients/financial-services/"},
# {"url":"https://www.roxboroughmemorial.com/patients-visitors/financial-assistance/"},
# {"url":"https://www.shrinerschildrens.org/en/standard-charges"},
# {"url":"https://towerhealth.org/locations/st-christophers-hospital-children/billing/hospital-pricing-st-christophers-hospital"},
# {"url":"https://www.slhn.org/billpay/patient-billing/price-transparency"},
# {"url":"https://www.suburbanhosp.org/patients-visitors/financial-assistance/"},
# {"url":"https://www.acmh.org/billing-and-insurance"},
# {"url":"https://ashospital.net/pricing-transparency/"},
# {"url":"https://www.ahn.org/patients-visitors/patients/financial-services/hospital-charges/"},
# {"url":"https://www.allied-services.org/resources/hospital-pricing-transparency/"},
# {"url":"http://www.barnes-kasson.org/index.php/resources/insurance-and-payment"},
# {"url":"https://www.belmontbehavioral.com/admissions/insurance-payment-information/rates-pricing/"},
# {"url":"https://berwickhospitalcenter.com/financial-arrangements/"},
# {"url":"https://www.brmc-ogh.org/visitors/billing-insurance-faq/"},
# {"url":"https://brookeglenhospital.com/standard-services/"},
# {"url":"https://www.butlerhealthsystem.org/patients-visitors/for-patients/financial-services/billable-service-fees/"},
# {"url":"https://www.windbercare.org/price-transparency/"},
# {"url":"https://www.chp.edu/for-parents/before-your-childs-visit/standard-charges"},
# {"url":"https://www.butlerhealthsystem.org/clarion-hospital/patients-visitors/for-patients/clarion-hospital-standard-charges/"},
# {"url":"https://clarioncenter.com/standard-services/"},
# {"url":"https://www.conemaugh.org/hospital-charges-listing"},
# {"url":"https://www.heritagevalley.org/patient-visitor-resources/pricing-transparency/"},
# {"url":"https://horshamclinic.com/standard-services/"},
# {"url":"https://www.irmc.org/patients-and-visitors/financial-services/price-transparency/"},
# {"url":"https://www.kindredhospitals.com/locations/ltac/kindred-hospital-philadelphia/patient-experience/what-to-expect"},
# {"url":"https://www.kindredhospitals.com/locations/ltac/kindred-hospital-philadelphia-havertown/patient-experience/what-to-expect"},
# {"url":"https://www.lancasterrehabhospital.com/patient-experience/financial-assistance"},
# {"url":"https://www.stmaryrehabilitationhospital.com/patient-experience/financial-assistance"},
# {"url":"https://www.lvhn.org/get-price-quote"},
# {"url":"https://mageerehab.jeffersonhealth.org/about-us/charge-description-master/"},
# {"url":"https://themeadows.net/standard-services/"},
# {"url":"https://www.mmchs.org/Patient-Visitors/Price-Transparency.aspx"},
# {"url":"https://www.commonwealthhealth.net/pricing-information"},
# {"url":"https://osshealth.com/oss-health-pricing"},
# {"url":"https://www.phhealthcare.org/patients-visitors/patient-billing-services"},
# {"url":"https://www.pennstatehealth.org/patients-visitors/billing-medical-records/understanding-cost-your-care"},
# {"url":"https://www.wellspanphilhaven.org/Patient-Resources/Cost-of-Care"},
# {"url":"https://www.pah.org/about/financial-assistance"},
# {"url":"https://towerhealth.org/locations/reading-hospital/billing/hospital-pricing-reading-hospital"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/camp-hill/camp-hill/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/danville/danville/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/erie/erie/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/harrisburg/harrisburg/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/johnstown/johnstown/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/latrobe/laurel-highlands/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/mckeesport/mckeesport/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/pittsburgh/pittsburgh-upmc/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/pa/york/york/"},
# {"url":"https://www.sharonregionalmedical.org/pricing-transparency"},
# {"url":"https://www.stclair.org/billing-insurance/cms-charge-disclosure/"},
# {"url":"https://sireading.com/hospital-pricing-information/"},
# {"url":"https://www.titusvillehospital.org/Patient-Visitors/Price-Transparency.aspx"},
# {"url":"https://www.uniontownhospital.com/ChargeTransparency"},
# {"url":"https://www.upmc.com/locations/hospitals/altoona/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/bedford/patients-visitors/patient-information/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/carlisle/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/cole/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/community-osteopathic/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/east/patients-and-visitors/patient-information/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/hamot/patients-visitors/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/hanover/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/harrisburg/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/horizon/patients-visitors/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/jameson/patients-visitors/patient-info/cdm"},
# {"url":"https://www.kanecommunityhospital.com/patient-and-visitor-information/upmc-kane-standard-charges/"},
# {"url":"https://www.upmc.com/locations/hospitals/lititz/patients-visitors/patient-info/cdm"},
# {"url":"https://www.upmc.com/locations/hospitals/lock-haven/patients-visitors/patient-info/cdm"},
# {"url":"https://billing.christianacare.org/transparency"},
# {"url":"https://www.frederickhealth.org/about/billing-financial-assistance/"},
# {"url":"https://www.umms.org/shore/patients-visitors/for-patients/hospital-charges"},
# {"url":"https://www.holycrosshealth.org/for-patients/billing-financial-assistance-and-insurance/charge-estimates#price"},
# {"url":"https://www.umms.org/capital/patients-visitors/hospital-charges"},
# {"url":"https://www.tidalhealth.org/medical-care/financial-admin-services/billing/hospital-based-price-billing-unit-information"},
# {"url":"https://www.meritushealth.com/patients-visitors/financial-disclosures-cms-price-transparency/"},
# {"url":"https://www.atlanticgeneral.org/patients-visitors/billing-information/procedure-pricing/"},
# {"url":"https://www.southeasthealth.org/financial-information-price-transparency/"},
# {"url":"https://mmcenters.com/charges"},
# {"url":"https://namccares.com/hospital-charges-listing"},
# {"url":"https://www.mizellmh.com/getpage.php"},
# {"url":"https://dekalbregional.com/pricing-transparency/"},
# {"url":"https://www.uabmedicine.org/price-transparency"},
# {"url":"https://www.huntsvillehospital.org/price-transparency"},
# {"url":"https://www.dalemedical.org/getpage.php"},
# {"url":"https://www.eastalabamahealth.org/patient-and-guests/billing-and-financial-information/estimate-my-cost"},
# {"url":"https://cullmanregional.com/patient-price-list/"},
# {"url":"https://www.andalusiahealth.com/hospital-charges-listing"},
# {"url":"https://www.gadsdenregional.com/pricing-information"},
# {"url":"https://www.dchsystem.com/patient-visitor/chargemaster/list-of-charges/"},
# {"url":"https://www.flowershospital.com/pricing-information"},
# {"url":"https://www.lawrencemedicalcenter.com/about/price-transparency"},
# {"url":"https://highlandsmedcenter.com/patients-visitors/price-transparency"},
# {"url":"https://russellcares.com/pricing/"},
# {"url":"https://northwestrh.org/home/patients-visitors/billing-finances/"},
# {"url":"https://halecountyhospital.com/pricing-1"},
# {"url":"https://www.dwmmh.org/getpage.php"},
# {"url":"https://www.infirmaryhealth.org/patients-visitors/community/cms-price-transparency-patient-estimates/"},
# {"url":"https://www.grandviewhealth.com/pricing-information"},
# {"url":"https://www.baptistfirst.org/financial/disclaimer-page-for-pricing"},
# {"url":"http://pcmc.care/Charge_Information.html#gsc.tab=0"},
# {"url":"https://www.bwwmh.com/healthinfo.html"},
# {"url":"https://www.vaughanregional.com/hospital-charges-listing"},
# {"url":"https://mchcare.com/patientsvisitors/"},
# {"url":"https://www.troymedicalcenter.com/patients-visitors/list-of-standard-charges-or-shoppable-services/"},
# {"url":"https://www.jmc.org/getpage.php"},
# {"url":"https://www.crestwoodmedcenter.com/pricing-information"},
# {"url":"https://www.springhillmedicalcenter.com/patients-visitors/patient-financial-resources/hospital-charges"},
# {"url":"https://www.namcshoals.com/hospital-charges-listing"},
# {"url":"https://www.yourcareeverywhere.com/content/medhost/your-care-everywhere/pricing-estimator-page.html"},
# {"url":"https://cvhealth.net/patients-visitors/patient-financial-information/price-transparency/"},
# {"url":"https://www.atmorehealth.org/getpage.php"},
# {"url":"https://trmc-al.com/hospital-pricing-transparency/"},
# {"url":"https://www.wchnh.org/getpage.php"},
# {"url":"https://healthy.kaiserpermanente.org/northern-california/doctors-locations/standard-charges"},
# {"url":"https://www.ochsnerrush.org/patients-visitors/hospital-pricing-transparency/"},
# {"url":"https://www.tanner.org/patients-and-visitors/billing-and-financial-resources/charges-for-care-at-tanner-hospitals"},
# {"url":"https://nolandhospitals.com/price-transparency/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/al/birmingham/birmingham/"},
# {"url":"https://amgihm.com/patient-notices/price-transparency/"},
# {"url":"https://encompasshealth.com/locations/lakeshorerehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/montgomeryrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/huntsvillerehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/dothanrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/shelbycountyrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/gadsdenrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/regionalrehab/transparency-healthcare"},
# {"url":"https://www.childrensal.org/patients-visitors/patient-billing-information/patient-billing-standard-charges"},
# {"url":"https://hillcrestbhs.com/standard-services/"},
# {"url":"https://laureloaksbhc.com/standard-services/"},
# {"url":"https://www.perimeterhealthcare.com/beacon-what-to-expect"},
# {"url":"https://www.providence.org/obp/pricing-transparency"},
# {"url":"https://www.matsuregional.com/pricing-information"},
# {"url":"https://www.bartletthospital.org/patients-visitors/estimate-of-charges/"},
# {"url":"https://www.alaskaregional.com/about/legal/pricing-transparency-cms-required-file-of-standard-charges.dot"},
# {"url":"https://www.cpgh.org/patients/patientfinancialservices/pricing/"},
# {"url":"https://anmc.org/pricing-transparency/"},
# {"url":"https://searhc.org/patient-support/price-transparency/para-price-transparency/"},
# {"url":"https://www.nortonsoundhealth.org/patient-resources/nshc-service-charges/"},
# {"url":"https://maniilaq.mdsave.com/"},
# {"url":"https://www.peacehealth.org/patient-financial-services/hospital-pricing"},
# {"url":"https://arcticslope.org/services/hospital-services/ssmh-chargemaster/"},
# {"url":"https://www.bannerhealth.com/es/patients/billing/pricing-resources/hospital-price-transparency"},
# {"url":"https://www.nahealth.com/billing-insurance/committed-price-transparency/"},
# {"url":"https://yrmc.org/patient-financial-services/direct-pay-pricing"},
# {"url":"https://www.yumaregional.org/For-Patients/Patient-Resources/Patient-Financial-Services/Transparency-in-Pricing"},
# {"url":"https://www.honorhealth.com/patients-visitors/average-pricing"},
# {"url":"https://www.tempestlukeshospital.org/pricing-transparency"},
# {"url":"https://www.canyonvistamedicalcenter.com/hospital-charges-listing"},
# {"url":"https://www.azkrmc.com/your-healthcare-costs"},
# {"url":"https://summithealthcare.net/summit-healthcare-transparency-report/"},
# {"url":"https://www.mtgraham.org/pricing-transparency/"},
# {"url":"https://www.mayoclinic.org/patient-visitor-guide/billing-insurance/price-estimates/chargemaster"},
# {"url":"https://www.thecoreinstitutehospital.com/patients-visitors/billing-options/"},
# {"url":"https://www.valleyviewmedicalcenter.net/hospital-charges-listing"},
# {"url":"https://www.mvmedicalcenter.org/pricing-transparency"},
# {"url":"https://oasishospital.com/hospital-pricing-information/"},
# {"url":"https://www.cancercenter.com/locations/phoenix/pricing-transparency"},
# {"url":"https://www.wickhosp.com/cdm/"},
# {"url":"https://sagememorial.com/insurance-billing-information/"},
# {"url":"https://pricetransparency.healthcare/copper-queen-community-hospital/charges/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/az/phoenix/phoenix/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/az/tucson/tucson-northwest/"},
# {"url":"https://www.chghospitals.com/location/cornerstone-specialty-hospitals-tucson/"},
# {"url":"http://phoenix.kpcph.com/cms-price-transparency/"},
# {"url":"https://encompasshealth.com/locations/scottsdalerehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/rehabinstituteoftucson/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/northwesttucsonrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/valleyofthesunrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/yumarehab/transparency-healthcare"},
# {"url":"https://mvrrh.ernesthealth.com/price-transparency/"},
# {"url":"https://encompasshealth.com/locations/eastvalleyrehab/transparency-healthcare"},
# {"url":"https://rhna.ernesthealth.com/price-transparency/"},
# {"url":"https://reunionrehabhospital.com/billing-information/"},
# {"url":"https://www.phoenixchildrens.org/price-information"},
# {"url":"https://www.stlukesbehavioralhealth.org/pricing-transparency"},
# {"url":"https://www.havenofphoenix.com/price-transparency/"},
# {"url":"https://www.sonorabehavioral.com/admissions/payment-insurance/rates-pricing/"},
# {"url":"https://tgcaz.org/behavioral-health-resources"},
# {"url":"https://www.obhhospital.com/about/payment-insurance/rates-pricing/"},
# {"url":"https://destinysprings.com/new-patients/insurance/"},
# {"url":"https://www.neuropsychiatrichospitals.net/pricing-transparency/"},
# {"url":"https://www.jrmc.com/jrmc/billing-services"},
# {"url":"https://www.wregional.com/main/pricing-transparency"},
# {"url":"https://www.chistvincent.com/patients-visitors/standard-charges"},
# {"url":"https://www.mercy.net/forms/items-and-services-files/"},
# {"url":"https://chambershospital.com/price-transparency-list/"},
# {"url":"https://www.unity-health.org/patients-visitors/pricing/"},
# {"url":"https://menaregional.com/"},
# {"url":"https://uamshealth.com/patients-and-guests/patient-support/billing/price-transparency/"},
# {"url":"https://www.baptist-health.com/hospital-charges-and-negotiated-rates/"},
# {"url":"https://forrestcitymedicalcenter.com/pricing-transparency/"},
# {"url":"https://www.saintmarysregional.com/hospital-charges-listing"},
# {"url":"https://www.ouachitamedcenter.com/patients-and-visitors/billing-information"},
# {"url":"https://drewmemorial.org/patients/standard-charges/"},
# {"url":"https://magnoliarmc.org/patient-and-visitors/billing-services/patient-pricing-information/"},
# {"url":"https://www.mchsys.org/getpage.php"},
# {"url":"https://nationalparkmedical.com/hospital-charges-listing"},
# {"url":"https://www.salinememorial.org/hospital-charges-listing"},
# {"url":"https://www.baptistonline.org/estimate-my-costs"},
# {"url":"https://pricing.arheart.com/pt-machinereadable.html"},
# {"url":"https://clariti-health.com/csp/clariti/QuotableService.csp?orgKey=9534EB"},
# {"url":"https://www.wadleyhealthathope.org/pricing-transparency"},
# {"url":"https://www.arkansascontinuedcarehospital.com/pricing-transparency"},
# {"url":"https://www.dardanelleregional.org/patients-visitors/billing-insurance/insurance-costs"},
# {"url":"https://mcgeheehospital.org/price-transparency/"},
# {"url":"https://www.ozarkhealth.net/ozark-health-costs"},
# {"url":"https://www.fultoncountyhospital.org/cost-of-services"},
# {"url":"https://www.bradleycountymedicalcenter.com/getpage.php"},
# {"url":"https://www.chicotmemorial.com/pfs/no-surprises-act/"},
# {"url":"https://piggotthealthsystem.com/standard-charges/"},
# {"url":"https://lhcgroup.com/locations/arkansas-extended-care-hospital-hot-springs/"},
# {"url":"https://www.selectspecialtyhospitals.com/locations-and-tours/ar/fort-smith/fort-smith/"},
# {"url":"https://lhcgroup.com/locations/arkansas-extended-care-hospital-fort-smith/"},
# {"url":"https://www.chghospitals.com/location/cornerstone-specialty-hospitals-little-rock/"},
# {"url":"https://encompasshealth.com/locations/fortsmithrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/jonesbororehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/stvincentrehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/fayettevillerehab/transparency-healthcare"},
# {"url":"https://encompasshealth.com/locations/stvhotsprings/transparency-healthcare"},
# {"url":"https://www.everestrehab.com/transparency.html"},
# {"url":"https://www.vantagepointnwa.com/admissions/insurance-information/rates-pricing/"},
# {"url":"https://humanservices.arkansas.gov/divisions-shared-services/aging-adult-behavioral-health-services/arkansas-state-hospital/"},
# {"url":"https://www.riverviewbehavioralhealth.com/admissions/payment-insurance/rates-pricing/"},
# {"url":"https://www.perimeterhealthcare.com/west-memphis-what-to-expect"},
# {"url":"https://www.strosehospital.org/patient_price_transparency"},
# {"url":"https://www.providence.org/obp/ca/ca-la/pricing-transparency"},
# {"url":"https://www.sutterhealth.org/for-patients/healthcare-cost-transparency"},
# {"url":"https://www.providence.org/locations/kadlec/regional-medical-center/patients-and-visitors/bill-pay/pricing-transparency"},
# {"url":"https://www.adventisthealth.org/patient-resources/financial-services/healthcare-costs-and-charges/cost-estimator-tool/"},
# {"url":"https://riversidecommunityhospital.com/about/legal/pricing-transparency-cms-required-file-of-standard-charges.dot"},
# {"url":"https://www.paradisevalleyhospital.net/patients-visitors/financial-services/"},
# {"url":"https://health.ucsd.edu/insurance-billing/standard-charges/Pages/default.aspx"},
# {"url":"https://www.sharp.com/chargemaster/grossmont/standard-charges.cfm"},
# {"url":"https://madriverhospital.com/patients-visitors/billing-insurance/"},
# {"url":"https://dhs.lacounty.gov/patient-information/get-coverage/hospital-price-transparency/"},
# {"url":"https://sgmh.org/"},
# {"url":"https://www.avmc.org/patients/billing-insurance-pricing/"},
# {"url":"https://www.kaweahhealth.org/patients-visitors/for-patients/costs-and-charges-billing-rates-/"},
# {"url":"https://www.communitymedical.org/for-patients-families/paymybill/hospital-standard-charges-(1)"},
# {"url":"https://www.hollywoodpresbyterian.com/billing-and-financial-services/"},
# {"url":"https://apps.para-hcfs.com/PTT/FinalLinks/OakValley_V2.aspx"},
# {"url":"https://www.scripps.org/patients-and-visitors/billing/price-transparency"},
ehab/transparency-healthcare"},
{"url":"https://encompasshealth.com/locations/midcitiesrehab/transparency-healthcare"},
{"url":"https://mri.ernesthealth.com/price-transparency/"},
{"url":"https://www.texasrehabhospital.com/patient-experience/financial-assistance-policy"},
{"url":"https://nbrrh.ernesthealth.com/price-transparency/"},
{"url":"https://encompasshealth.com/locations/houston/cypressrehab/transparency-healthcare"},
{"url":"https://encompasshealth.com/locations/houston/thevintagerehab/transparency-healthcare"},
{"url":"https://ccrh.ernesthealth.com/price-transparency/"},
{"url":"https://encompasshealth.com/locations/austinrehab/transparency-healthcare"},
{"url":"https://pamhealth.com/facilities/find-facility/rehabilitation-hospitals/pam-rehabilitation-hospital-victoria"},
{"url":"https://pamhealth.com/facilities/find-facility/rehabilitation-hospitals/pam-rehabilitation-hospital-kyle"},
{"url":"https://lrh.ernesthealth.com/price-transparency/"},
{"url":"https://pamhealth.com/facilities/find-facility/rehabilitation-hospitals/pam-rehabilitation-hospital-clear-lake"},
{"url":"https://clearskyhealth.com/weatherford/about-us/pricing-transparency/"},
{"url":"https://trhl.ernesthealth.com/price-transparency/"},
{"url":"https://encompasshealth.com/locations/stjrehab/transparency-healthcare"},
{"url":"https://encompasshealth.com/locations/houston/pearlandrehab/transparency-healthcare"},
{"url":"https://pamhealth.com/facilities/find-facility/rehabilitation-hospitals/pam-health-rehabilitation-hospital-corpus-christi"},
{"url":"https://pamhealth.com/facilities/find-facility/rehabilitation-hospitals/pam-rehabilitation-hospital-round-rock"},
{"url":"https://encompasshealth.com/locations/southplainsrehab/transparency-healthcare"},
{"url":"https://encompasshealth.com/locations/houston/katyrehab/transparency-healthcare"},
{"url":"https://clearskyhealth.com/flowermound/about-us/pricing-transparency/"},
{"url":"https://www.texasrehabkeller.com/patient-experience/financial-assistance"},
{"url":"https://encompasshealth.com/locations/sanangelorehab/transparency-healthcare"},
{"url":"https://encompasshealth.com/locations/wacorehab/transparency-healthcare"},
{"url":"https://encompasshealth.com/locations/shreveportrehab/transparency-healthcare"}
]
output_folder = 'downloaded_csvs_2'
download_csv_files(dataset, output_folder)

# %%
import glob
import os
import pandas as pd



# Specify the path to your folder containing CSV files
path = r'C:/Users/kripa.krishnan/Desktop/Chargemasters/'

# Get a list of all CSV files with 'standard_charges' in the filename
all_files = glob.glob(os.path.join(path, '*standardcharges*.csv'))

# Initialize an empty list to store DataFrames
dfs = []

file_counter = 0

# Read each CSV file and append its contents to the list
for filename in all_files:
    try:
        df = pd.read_csv(filename, encoding='Latin-1', comment = '#')
        print(filename)
        # Filter columns with "code" and "Charge" in their names
        relevant_columns = [col for col, column in enumerate(df.transpose().values) if any ('CPT' in str(value)for value in column)]
        if not relevant_columns:
            continue
        df_col = df.iloc[:, relevant_columns]
        dfs.append(df_col)

        file_counter += 1
        print(file_counter)

        if file_counter % 25 == 0:
                input(f"Processed{file_counter} CSV files. Press enter to continue or Ctrl+C to exit...")
        #print(dfs)
        # Add additional checks here if needed (e.g., column names, data format)
        # For example, if 'PROD_NAME' is a required column:
        #if 'PROD_NAME' in df.columns:
        #dfs.append(df)
       # else:
        #    print(f"Skipping {filename}: Missing 'PROD_NAME' column")
    except pd.errors.ParserError:
        print(f"Skipping {filename}: Invalid CSV format")

# Concatenate all DataFrames into a single large DataFrame
big_frame = pd.concat(dfs, ignore_index=True)

# Now 'big_frame' contains the stacked data from all CSV files
print(big_frame.head())  # You can adjust this line to display or save the DataFrame as needed
